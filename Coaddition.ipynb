# %% [markdown]
# # Coaddition-Subtraction method for transient objects detection

# %% [markdown]
# Imports of all LSST Python modules necessaries for the processing

# %%
import glob
import os
import subprocess
import sys
import lsst.pipe.tasks.ingest as Ingester
import lsst.pipe.tasks.processCcd as Processer
import lsst.pipe.base.argumentParser as ArgumentParser
import lsst.daf.persistence as dafPersist
import lsst.pipe.tasks.makeSkyMap as SkyMapper

import lsst.pipe.tasks.reportPatches as PatchReporter
import lsst.pipe.tasks.makeCoaddTempExp as TempexpCoadder
import lsst.pipe.tasks.assembleCoadd as Assembler

import lsst.afw.image as afwImage
import lsst.meas.algorithms as measAlg
import lsst.ip.diffim as ipDiffim
import lsst.ip.diffim.diffimTools as diffimTools

DATADIR="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS"
DATASUB1="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1"
DATASUB2="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB2"
DATASUB3="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB3"
DATASUB4="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB4"
DATASUB5="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB5"

# %% [markdown]
# Working directory is created. A reference to the cam mapper is also created.

# %%
os.makedirs(DATADIR)
os.makedirs(DATADIR+"/input")
temp_file=open(DATADIR+"/input/_mapper",'w')
temp_file.write('lsst.obs.cfht.MegacamMapper')
temp_file.close()

# %% [markdown]
# We need to instantiate the task as well as the configuration and parser classes.
#
# IMPORTANT: a file _mapper has to exist in the input folder with the line 'lsst.echo.cfht.MegacamMapper' or the method will not run!
#
# Usually, by command line, a wildcard can be used to express a list of files. However, the wildcard is interpreted by the shell and split in a long line with all the list of arguments. In order to ensure that the same is beind done here, we have to manually generate the list from the wildcard and put in a valid string format.

# %%
ITask = Ingester.IngestTask
IConfig = ITask.ConfigClass()
IParser = ITask.ArgumentParser("ingest")
Files = glob.glob(DATADIR+"/../../../data/rawnew3/996721p.fits.fz")
SFiles = ' '.join(Files)
print(SFiles)

# %% [markdown]
# Parameters should be given to the parser the same way they should be used as parameter though the terminal

# %%
args = IParser.parse_args(IConfig, (DATADIR+'/input '+SFiles+' --mode link').split()) 
task = ITask(config=args.config)
task.run(args)

# %% [markdown]
# Run and process all the CCDs

# %%
PTask = Processer.ProcessCcdTask

PTask.parseAndRun(args=((DATADIR+"/input --output "+DATADIR+"/output --id ccd=0^1^2^9^10^11 --config isr.doBias=False isr.doFlat=False isr.doFringe=False").split()))

# %% [markdown]
# A sky map is created on the area of interest

# %%
subprocess.call(["ln","-s",DATADIR+"/output", DATADIR+"/output/calexp/_parent"])
SMTask = SkyMapper.MakeSkyMapTask
res=SMTask.parseAndRun(args=(DATADIR+"/output/calexp --config  skyMap.active.decList=51.0,54.0  skyMap.active.raList=213.0,216.0  --output "+DATADIR+"/output/coadd_r_dir").split())

# %% [markdown]
# The zone containint the ccds has to be delimited

# %%
stdout = sys.stdout
sys.stdout = open(DATADIR+"/patches.txt", 'w')
RPTask = PatchReporter.ReportPatchesTask
res=RPTask.parseAndRun(args=(DATADIR+'/output/coadd_r_dir --config raDecRange=213.0,51.0,216.0,54.0 --id tract=0 patch=0,0 filter=r').split()) 
sys.stdout = open(DATADIR+"/patches_r.txt", 'w')
subprocess.call(["sed", "-e", 's/^/--id filter=r /', DATADIR+"/patches.txt"],stdout=sys.stdout)
sys.stdout =stdout

# %% [markdown]
# The first part of the coaddition is launched to make the coaddition of the images

# %%
TCTask = TempexpCoadder.MakeCoaddTempExpTask
res=TCTask.parseAndRun(args=((DATADIR+"/output/calexp --output "+DATADIR+"/output/coadd_r_dir @"+DATADIR+"/patches_r.txt --selectId filter=r").split()))

# %% [markdown]
# Result images from coaddition are assembled according to the sky map defined

# %%
ACTask = Assembler.AssembleCoaddTask
res=ACTask.parseAndRun(args=((DATADIR+"/output/coadd_r_dir @"+DATADIR+"/patches_r.txt --selectId filter=r").split()))

# %% [markdown]
# Subtraction:

# %% [markdown]
# The two folders containing the images to subtract are defined

# %%
Set1Path = "/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS/output/coadd_r_dir/deepCoadd/r/1/9,2.fits"
Set2Path = "/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_S1/output/coadd_r_dir/deepCoadd/r/1/9,2.fits"
OutputPath = "/renoir_data_00/jpreyes/stacks/notebook_files/data/subtraction"

# %% [markdown]
# The images are loaded and subtracted. Results are saved on disk.

# %%
config = ipDiffim.ImagePsfMatchTask.ConfigClass()
config.kernel.name = "AL"
subconfig = config.kernel.active
defFwhm         = 4.5
fwhmS = defFwhm
fwhmT = defFwhm
psfmatch = ipDiffim.ImagePsfMatchTask(config)

#for image1, image2 in zip(Set1Files,Set2Files):
#    print("Subtracting " + image1 + " " + image2)
firstImage = afwImage.ExposureF(Set1Path)
secondImage = afwImage.ExposureF(Set2Path)
    
results  = psfmatch.subtractExposures(firstImage, secondImage,
                            templateFwhmPix = fwhmT, scienceFwhmPix = fwhmS)
differenceExposure = results.subtractedExposure
differenceExposure.writeFits(OutputPath+'/S1R/9,2.fits')

# %%
import lsst.pipe.tasks.processCoadd as CoaddProcesser

CPTask = CoaddProcesser.ProcessCoaddTask
#CPTask.parseAndRun(args=((DATASUB3+"/output/coadd_r_dir --output "+DATASUB3+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB3+"/patches_r.txt").split()))
CPTask.parseAndRun(args=((DATASUB1+"/output/coadd_r_dir --output "+DATASUB1+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB1+"/patches_r.txt").split()))
#CPTask.parseAndRun(args=((DATASUB5+"/output/coadd_r_dir --output "+DATASUB5+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB5+"/patches_r.txt").split()))
# Out:
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,7.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,7.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,8.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,8.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,9.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,9.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,10.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,10.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,11.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,11.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,12.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,12.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,13.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,13.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,14.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/0,14.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,7.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,7.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,8.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,8.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,9.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,9.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,10.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,10.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,11.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,11.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,12.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,12.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,13.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,13.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,14.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/1,14.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/2,7.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/2,7.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/2,8.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/0/2,8.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
# ...
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,5.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,5.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,6.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,6.fits' with mode 'r''
#
# Traceback (most recent call last):
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,7.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/7,7.fits' with mode 'r''
#
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-11e8d994e668> in <module>()
#       3 CPTask = CoaddProcesser.ProcessCoaddTask
#       4 #CPTask.parseAndRun(args=((DATASUB3+"/output/coadd_r_dir --output "+DATASUB3+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB3+"/patches_r.txt").split()))
# ----> 5 CPTask.parseAndRun(args=((DATASUB1+"/output/coadd_r_dir --output "+DATASUB1+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB1+"/patches_r.txt").split()))
#       6 #CPTask.parseAndRun(args=((DATASUB5+"/output/coadd_r_dir --output "+DATASUB5+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB5+"/patches_r.txt").split()))
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.pyc in parseAndRun(cls, args, config, log, doReturnResults)
#     428         parsedCmd = argumentParser.parse_args(config=config, args=args, log=log, override=cls.applyOverrides)
#     429         taskRunner = cls.RunnerClass(TaskClass=cls, parsedCmd=parsedCmd, doReturnResults=doReturnResults)
# --> 430         resultList = taskRunner.run(parsedCmd)
#     431         return Struct(
#     432             argumentParser = argumentParser,
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.pyc in run(self, parsedCmd)
#     193             with profile(profileName, log):
#     194                 # All the work is done here
# --> 195                 resultList = mapFunc(self, self.getTargetList(parsedCmd))
#     196         else:
#     197             resultList = []
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.pyc in __call__(self, args)
#     313         else:
#     314             try:
# --> 315                 result = task.run(dataRef, **kwargs)
#     316             except Exception, e:
#     317                 task.log.fatal("Failed on dataId=%s: %s" % (dataRef.dataId, e))
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.pyc in wrapper(self, *args, **keyArgs)
#     116         logInfo(obj = self, prefix = func.__name__ + "Start")
#     117         try:
# --> 118             res = func(self, *args, **keyArgs)
#     119         finally:
#     120             logInfo(obj = self, prefix = func.__name__ + "End")
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.pyc in run(self, dataRef)
#     137             coadd = dataRef.get(self.config.coaddName + "Coadd")
#     138             if self.config.doScaleVariance:
# --> 139                 self.scaleVariance(coadd)
#     140
#     141         # delegate most of the work to ProcessImageTask
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.pyc in wrapper(self, *args, **keyArgs)
#     116         logInfo(obj = self, prefix = func.__name__ + "Start")
#     117         try:
# --> 118             res = func(self, *args, **keyArgs)
#     119         finally:
#     120             logInfo(obj = self, prefix = func.__name__ + "End")
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.pyc in scaleVariance(self, exposure)
#     102         ctrl = afwMath.StatisticsControl()
#     103         ctrl.setAndMask(~0x0)
# --> 104         var    = exposure.getMaskedImage().getVariance()
#     105         mask   = exposure.getMaskedImage().getMask()
#     106         dstats = afwMath.makeStatistics(exposure.getMaskedImage(), afwMath.VARIANCECLIP, ctrl).getValue(afwMath.VARIANCECLIP)
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.pyc in __getattribute__(self, attr, oga)
#      39
#      40     def __getattribute__(self, attr, oga=object.__getattribute__):
# ---> 41         subject = oga(self, '__subject__')
#      42         if attr == '__subject__':
#      43             return subject
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.pyc in __subject__(self, get_cache, set_cache)
#     134         return get_cache(self)
#     135     except AttributeError:
# --> 136         set_cache(self, get_callback(self)())
#     137         return get_cache(self)
#     138
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.pyc in <lambda>()
#     240             innerCallback = callback
#     241             callback = lambda: self.mapper.standardize(datasetType,
# --> 242                     innerCallback(), dataId)
#     243         if immediate:
#     244             return callback()
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.pyc in <lambda>()
#     236                     location, dataId)
#     237         else:
# --> 238             callback = lambda: self._read(pythonType, location)
#     239         if self.mapper.canStandardize(datasetType):
#     240             innerCallback = callback
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.pyc in _read(self, pythonType, location)
#     424                 storageList.append(storage)
#     425                 itemData = self.persistence.unsafeRetrieve(
# --> 426                         location.getCppType(), storageList, additionalData)
#     427                 finalItem = pythonType.swigConvert(itemData)
#     428             trace.done()
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.pyc in unsafeRetrieve(self, *args)
#    1428     def unsafeRetrieve(self, *args):
#    1429         """unsafeRetrieve(Persistence self, std::string const & persistableType, StorageList storageList, lsst::daf::base::PropertySet::Ptr additionalData) -> Persistable"""
# -> 1430         return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
#    1431
#    1432     def getPersistence(*args):
#
# KeyboardInterrupt:
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/cmdLineTask.py", line 315, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 139, in run
#     self.scaleVariance(coadd)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_tasks/9.2/python/lsst/pipe/tasks/processCoadd.py", line 104, in scaleVariance
#     var    = exposure.getMaskedImage().getVariance()
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 41, in __getattribute__
#     subject = oga(self, '__subject__')
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/readProxy.py", line 136, in __subject__
#     set_cache(self, get_callback(self)())
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 242, in <lambda>
#     innerCallback(), dataId)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 238, in <lambda>
#     callback = lambda: self._read(pythonType, location)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.py", line 426, in _read
#     location.getCppType(), storageList, additionalData)
#   File "/renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/persistenceLib.py", line 1430, in unsafeRetrieve
#     return _persistenceLib.Persistence_unsafeRetrieve(self, *args)
# FitsError:
#   File "src/fits.cc", line 1071, in lsst::afw::fits::Fits::Fits(const std::string&, const std::string&, int)
#     cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/8,0.fits' with mode 'r' {0}
# lsst::afw::fits::FitsError: 'cfitsio error: could not open the named file (104) : Opening file '/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1/output/coadd_r_dir/deepCoaddDetect/deepCoadd/r/1/8,0.fits' with mode 'r''
