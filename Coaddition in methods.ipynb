# %% [markdown]
# # Coaddition-Subtraction method for transient objects detection

# %% [markdown]
# Imports of all LSST Python modules necessaries for the processing

# %%
import glob
import os
import subprocess
import sys



from IPython.display import Image, display_png

import lsst.afw.display.ds9 as ds9

import lsst.pipe.tasks.ingest as Ingester
import lsst.pipe.tasks.processCcd as Processer
import lsst.pipe.base.argumentParser as ArgumentParser
import lsst.daf.persistence as dafPersist
import lsst.pipe.tasks.makeSkyMap as SkyMapper

import lsst.pipe.tasks.reportPatches as PatchReporter
#import reportPatches as PatchReporter
import lsst.pipe.tasks.makeCoaddTempExp as TempexpCoadder
import lsst.pipe.tasks.assembleCoadd as Assembler

import lsst.afw.image as afwImage
import lsst.meas.algorithms as measAlg
import lsst.ip.diffim as ipDiffim
import lsst.ip.diffim.diffimTools as diffimTools

#DATADIR="/sps/lsst/data/jreyes/CFHTLS"
DATADIR="/renoir_data_02/fouchez/lsst_data/data/CFHTLS"

#DATADIR="/renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/
#DATASUB1="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB1"
#DATASUB2="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB2"
#DATASUB3="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB3"
#DATASUB4="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB4"
#DATASUB5="/renoir_data_00/jpreyes/stacks/notebook_files/data/CFHTLS_SUB5"

# %% [markdown]
# Methods for ds9 image visualization

# %%
def displayFigure(path):
    i =  Image(path)
    display_png(i)
    
def displayImage(Image,frame=0,title="NoName",path="fig"):
    ds9.mtv(Image, frame=frame, title=title)
    ds9.ds9Cmd("zscale")
    ds9.ds9Cmd("zoom to fit")
    ds9.ds9Cmd("raise")
    ds9.ds9Cmd('saveimage '+path)
    print title
    displayFigure(path)

def showFrame(frame=0,title="NoTitle",path="fig"):
    ds9.ds9Cmd("zscale")
   # ds9.ds9Cmd("zoom to fit")
    ds9.ds9Cmd("raise")
    ds9.ds9Cmd('saveimage '+path)
    print title
    displayFigure(path)
    
def displayImageWithSources(Image,frame=0,title="NoName",path="fig", sources=[]):
    ds9.mtv(Image, frame=frame, title=title)
    ds9.ds9Cmd("zscale")
    ds9.ds9Cmd("zoom to fit")
    ds9.ds9Cmd("raise")
    
    
    for source in sources:
        ds9.dot("+", source.getX()-Image.getX0()  , source.getY()-Image.getY0() , frame=frame, size = 25, ctype = ds9.RED)

    
    ds9.ds9Cmd('saveimage '+path)
    print title
    displayFigure(path)

# %% [markdown]
# Working directory is created. A reference to the cam mapper is also created.

# %%
if(os.path.exists(DATADIR)==False):
    os.makedirs(DATADIR)
if(os.path.exists(DATADIR+"/input")==False):
    os.makedirs(DATADIR+"/input")
temp_file=open(DATADIR+"/input/_mapper",'w')
temp_file.write('lsst.obs.cfht.MegacamMapper')
temp_file.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-88b56198b5d5> in <module>()
#       3 if(os.path.exists(DATADIR+"/input")==False):
#       4     os.makedirs(DATADIR+"/input")
# ----> 5 temp_file=open(DATADIR+"/input/_mapper",'w')
#       6 temp_file.write('lsst.obs.cfht.MegacamMapper')
#       7 temp_file.close()
#
# IOError: [Errno 13] Permission denied: '/renoir_data_02/fouchez/lsst_data/data/CFHTLS/input/_mapper'

# %% [markdown]
# We need to instantiate the task as well as the configuration and parser classes.
#
# IMPORTANT: a file _mapper has to exist in the input folder with the line 'lsst.echo.cfht.MegacamMapper' or the method will not run!
#
# Usually, by command line, a wildcard can be used to express a list of files. However, the wildcard is interpreted by the shell and split in a long line with all the list of arguments. In order to ensure that the same is beind done here, we have to manually generate the list from the wildcard and put in a valid string format.

# %%
ITask = Ingester.IngestTask
IConfig = ITask.ConfigClass()
IParser = ITask.ArgumentParser("ingest")
Files = glob.glob("/renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/99475*.fits.fz")
SFiles = ' '.join(Files)
print(SFiles)
# Out:
# /renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/994755p.fits.fz /renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/994756p.fits.fz /renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/994757p.fits.fz /renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/994758p.fits.fz /renoir_data_02/lsst_data/CFHT/rawElixir/D3/r/994759p.fits.fz

# %% [markdown]
# Parameters should be given to the parser the same way they should be used as parameter though the terminal

# %%
args = IParser.parse_args(IConfig, (DATADIR+'/input '+SFiles+' --mode link').split()) 
task = ITask(config=args.config)
task.run(args)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-6de4f85801ad> in <module>()
# ----> 1 args = IParser.parse_args(IConfig, (DATADIR+'/input '+SFiles+' --mode link').split())
#       2 task = ITask(config=args.config)
#       3 task.run(args)
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/pipe_base/9.2/python/lsst/pipe/base/argumentParser.pyc in parse_args(self, config, args, log, override)
#     351         namespace.config = config
#     352         namespace.log = log if log is not None else pexLog.Log.getDefaultLog()
# --> 353         mapperClass = dafPersist.Butler.getMapperClass(inputRoot)
#     354         namespace.camera = mapperClass.getCameraName()
#     355         namespace.obsPkg = mapperClass.getEupsProductName()
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/daf_persistence/9.0+7/python/lsst/daf/persistence/butler.pyc in getMapperClass(root)
#     107             raise RuntimeError("Unqualified mapper name %s in %s" %
#     108                     (mapperName, mapperFile))
# --> 109         pkg = importlib.import_module(".".join(components[:-1]))
#     110         return getattr(pkg, components[-1])
#     111
#
# /renoir_data_00/jpreyes/stacks/v9_2_copy/Linux64/anaconda/1.8.0/lib/python2.7/importlib/__init__.pyc in import_module(name, package)
#      35             level += 1
#      36         name = _resolve_name(name[level:], package, level)
# ---> 37     __import__(name)
#      38     return sys.modules[name]
#
# ImportError: No module named cfht

# %% [markdown]
# Run and process all the CCDs

# %%
PTask = Processer.ProcessCcdTask

PTask.parseAndRun(args=((DATADIR+"/input --output "+DATADIR+"/output --id ccd=14 --config isr.doBias=False isr.doFlat=False isr.doFringe=False").split()))
# Out:
# /sps/lsst/Library/stack_v10_0/Linux64/anaconda/2.1.0/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /sps/lsst/Library/stack_v10_0/Linux64/anaconda/2.1.0/lib/python2.7/site-packages/numpy/core/_methods.py:71: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /sps/lsst/Library/stack_v10_0/Linux64/meas_algorithms/10.0+2/python/lsst/meas/algorithms/objectSizeStarSelector.py:144: RuntimeWarning: invalid value encountered in less
#   update = dist < minDist
# Traceback (most recent call last):
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/cmdLineTask.py", line 316, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processCcd.py", line 82, in run
#     result = self.process(sensorRef, postIsrExposure)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processImage.py", line 158, in process
#     calib = self.calibrate.run(inputExposure, idFactory=idFactory)
#   File "/sps/lsst/dev/lsstprod/CFHT/my_package/DM-1593/obs_cfht/python/lsst/obs/cfht/cfhtCalibrate.py", line 123, in run
#     astromRet = self.astrometry.run(exposure, sources)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 200, in run
#     results = self.astrometry(exposure, sources, bbox=bbox)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 317, in astrometry
#     astrom = self.astrometer.determineWcs(sources, exposure, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 405, in determineWcs
#     return self.determineWcs2(sources, **margs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 428, in determineWcs2
#     wcs,qa = self.getBlindWcsSolution(sources, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 516, in getBlindWcsSolution
#     raise RuntimeError("Unable to match sources with catalog.")
# RuntimeError: Unable to match sources with catalog.
# Traceback (most recent call last):
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/cmdLineTask.py", line 316, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processCcd.py", line 82, in run
#     result = self.process(sensorRef, postIsrExposure)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processImage.py", line 158, in process
#     calib = self.calibrate.run(inputExposure, idFactory=idFactory)
#   File "/sps/lsst/dev/lsstprod/CFHT/my_package/DM-1593/obs_cfht/python/lsst/obs/cfht/cfhtCalibrate.py", line 123, in run
#     astromRet = self.astrometry.run(exposure, sources)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 200, in run
#     results = self.astrometry(exposure, sources, bbox=bbox)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 317, in astrometry
#     astrom = self.astrometer.determineWcs(sources, exposure, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 405, in determineWcs
#     return self.determineWcs2(sources, **margs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 428, in determineWcs2
#     wcs,qa = self.getBlindWcsSolution(sources, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 516, in getBlindWcsSolution
#     raise RuntimeError("Unable to match sources with catalog.")
# RuntimeError: Unable to match sources with catalog.
# Traceback (most recent call last):
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/cmdLineTask.py", line 316, in __call__
#     result = task.run(dataRef, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processCcd.py", line 82, in run
#     result = self.process(sensorRef, postIsrExposure)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/processImage.py", line 158, in process
#     calib = self.calibrate.run(inputExposure, idFactory=idFactory)
#   File "/sps/lsst/dev/lsstprod/CFHT/my_package/DM-1593/obs_cfht/python/lsst/obs/cfht/cfhtCalibrate.py", line 123, in run
#     astromRet = self.astrometry.run(exposure, sources)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 200, in run
#     results = self.astrometry(exposure, sources, bbox=bbox)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_base/10.0+2/python/lsst/pipe/base/timer.py", line 118, in wrapper
#     res = func(self, *args, **keyArgs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/pipe_tasks/10.0+1/python/lsst/pipe/tasks/astrometry.py", line 317, in astrometry
#     astrom = self.astrometer.determineWcs(sources, exposure, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 405, in determineWcs
#     return self.determineWcs2(sources, **margs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 428, in determineWcs2
#     wcs,qa = self.getBlindWcsSolution(sources, **kwargs)
#   File "/sps/lsst/Library/stack_v10_0/Linux64/meas_astrom/10.0+2/python/lsst/meas/astrom/astrom.py", line 516, in getBlindWcsSolution
#     raise RuntimeError("Unable to match sources with catalog.")
# RuntimeError: Unable to match sources with catalog.
# /sps/lsst/Library/stack_v10_0/Linux64/meas_algorithms/10.0+2/python/lsst/meas/algorithms/objectSizeStarSelector.py:340: RuntimeWarning: invalid value encountered in less
#   bad = numpy.logical_or(bad, width < self._widthMin)
# /sps/lsst/Library/stack_v10_0/Linux64/meas_algorithms/10.0+2/python/lsst/meas/algorithms/objectSizeStarSelector.py:341: RuntimeWarning: invalid value encountered in greater
#   bad = numpy.logical_or(bad, width > self._widthMax)
# Struct(taskRunner=<lsst.pipe.base.cmdLineTask.TaskRunner object at 0x7fb3b6967950>; parsedCmd=Namespace(butler=<lsst.daf.persistence.butler.Butler object at 0x7fb3b6764910>, calib=None, camera='megacam', clobberConfig=False, clobberOutput=False, config=lsst.pipe.tasks.processCcd.ProcessCcdConfig(doIsr=True, doWriteHeavyFootprintsInSources=False, doWriteSources=True, isr={'assembleCcd': {'doTrim': True, 'keysToRemove': [], 'setGain': False, 'doRenorm': False}, 'fringe': {'stats': {'badMaskPlanes': ['SAT'], 'stat': 32, 'clip': 3.0, 'iterations': 3}, 'filters': ['i', 'i2', 'z'], 'clip': 3.0, 'large': 50, 'num': 30000, 'iterations': 20, 'small': 1, 'pedestal': True}, 'doAssembleDetrends': True, 'overscanOrder': 1, 'doWrite': False, 'saturatedMaskName': 'SAT', 'fringeAfterFlat': False, 'doDark': False, 'setGainAssembledCcd': True, 'flatScalingType': 'USER', 'doFlat': False, 'doFringe': False, 'overscanRej': 3.0, 'keysToRemoveFromAssembledCcd': [], 'fluxMag0T1': 10000000000.0, 'growSaturationFootprintSize': 1, 'fwhm': 1.0, 'overscanFitType': 'MEDIAN', 'doBias': False, 'flatUserScale': 1.0}, doDetection=True, doWriteSourceMatches=False, detection={'reEstimateBackground': True, 'nSigmaToGrow': 2.4, 'minPixels': 1, 'includeThresholdMultiplier': 1.0, 'isotropicGrow': False, 'adjustBackground': 0.0, 'thresholdType': 'stdev', 'background': {'ignoredPixelMask': ['EDGE', 'DETECTED', 'DETECTED_NEGATIVE'], 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'algorithm': 'NATURAL_SPLINE', 'binSize': 256, 'isNanSafe': False, 'statisticsProperty': 'MEANCLIP'}, 'returnOriginalFootprints': True, 'thresholdPolarity': 'positive', 'thresholdValue': 5.0}, doWriteCalibrateMatches=True, doDeblend=False, calibrate={'initialPsf': {'fwhm': 1.0, 'model': 'SingleGaussian', 'pixelScale': 0.25, 'size': 15}, 'repair': {'doInterpolate': True, 'doCosmicRay': True, 'cosmicray': {'keepCRs': False, 'cond3_fac2': 0.4, 'cond3_fac': 2.5, 'nCrPixelMax': 100000, 'niteration': 3, 'minSigma': 6.0, 'min_DN': 150.0}}, 'doPsf': True, 'astrometry': {'rejectIter': 3, 'forceKnownWcs': False, 'rejectThresh': 3.0, 'solver': {'cleaningParameter': 3.0, 'pixelScaleUncertainty': 1.1, 'catalogMatchDist': 1.0, 'useWcsParity': True, 'sipOrder': 4, 'useWcsRaDecCenter': True, 'matchThreshold': 27.631021115928547, 'useWcsPixelScale': True, 'maxStars': 50, 'badFlags': [], 'allFluxes': True, 'calculateSip': True, 'maxCpuTime': 0.0, 'filterMap': {'i2': 'i'}, 'raDecSearchRadius': 1.0}}, 'doBackground': True, 'detection': {'reEstimateBackground': True, 'nSigmaToGrow': 2.4, 'minPixels': 1, 'includeThresholdMultiplier': 10.0, 'isotropicGrow': False, 'adjustBackground': 0.0, 'thresholdType': 'stdev', 'background': {'ignoredPixelMask': ['EDGE', 'DETECTED', 'DETECTED_NEGATIVE'], 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'algorithm': 'NATURAL_SPLINE', 'binSize': 256, 'isNanSafe': False, 'statisticsProperty': 'MEANCLIP'}, 'returnOriginalFootprints': True, 'thresholdPolarity': 'positive', 'thresholdValue': 5.0}, 'doPhotoCal': True, 'initialMeasurement': {'noiseReplacer': {'noiseSeed': 0, 'noiseOffset': 0.0, 'noiseSource': 'measure'}, 'slots': {'psfFlux': 'base_PsfFlux', 'apFlux': 'base_SincFlux', 'instFlux': 'base_GaussianFlux', 'shape': 'base_SdssShape', 'centroid': 'base_SdssCentroid', 'modelFlux': 'base_GaussianFlux'}, 'doReplaceWithNoise': True, 'plugins': {'values': {'base_CircularApertureFlux': {'doMeasure': True, 'shiftKernel': 'lanczos5', 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'executionOrder': 2.0, 'maxSincRadius': 10.0}, 'base_NaiveCentroid': {'doMeasure': True, 'executionOrder': 0.0, 'background': 0.0}, 'base_PixelFlags': {'doMeasure': True, 'executionOrder': 2.0}, 'base_SkyCoord': {'doMeasure': True, 'executionOrder': 5.0}, 'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': [], 'executionOrder': 2.0}, 'base_NaiveFlux': {'doMeasure': True, 'executionOrder': 2.0, 'radius': 7.0}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4', 'executionOrde ...

# %% [markdown]
# A sky map is created on the area of interest

# %%
subprocess.call(["ln","-s",DATADIR+"/output", DATADIR+"/output/calexp/_parent"])
SMTask = SkyMapper.MakeSkyMapTask
res=SMTask.parseAndRun(args=(DATADIR+"/output/calexp --config  skyMap.active.decList=52.5,53.5  skyMap.active.raList=214.0,215.0 skyMap.active.patchInnerDimensions=1000,1000 --clobber-config --output "+DATADIR+"/output/coadd_r_dir/subtract").split())

# %% [markdown]
# ## Coaddition of Images

# %%
def Coaddition(path='coaddImages', tract=0, filter=None, visitList=None):
    
    visitStr = ''
    for visit in visitList : visitStr = visitStr +'^'+str(visit) 
    visitStr = visitStr[1:]
    print visitStr
    
    CoaddDir = DATADIR+'/output/coadd_r_dir/'+path
    
    if(os.path.exists(CoaddDir)==False):
        os.makedirs(CoaddDir)

    subprocess.call(["ln","-s",DATADIR+"/output", DATADIR+"/output/calexp/_parent"])
    SMTask = SkyMapper.MakeSkyMapTask
    res=SMTask.parseAndRun(args=(DATADIR+"/output/calexp --config  skyMap.active.decList=52.5,53.5  skyMap.active.raList=214.0,215.0 skyMap.active.patchInnerDimensions=1000,1000 --clobber-config --output "+DATADIR+"/output/coadd_r_dir/"+path).split())
    
        
    #Delimiting the zone
    stdout = sys.stdout
    sys.stdout = open(DATADIR+"/patches.txt", 'w')
    RPTask = PatchReporter.ReportPatchesTask
    res=RPTask.parseAndRun(args=(DATADIR+'/output/coadd_r_dir/'+path+' --config raDecRange=214.0,52.5,215.0,53.5 --id tract='+str(tract)+' patch=0,0 filter='+filter+' --clobber-config').split()) 
    sys.stdout = open(DATADIR+"/patches_r.txt", 'w')
    subprocess.call(["sed", "-e", 's/^/--id filter=r /', DATADIR+"/patches.txt"],stdout=sys.stdout)
    sys.stdout =stdout
    
    #Create the patches to be coadded
    TCTask = TempexpCoadder.MakeCoaddTempExpTask
    res=TCTask.parseAndRun(args=((DATADIR+"/output/calexp --output "+DATADIR+"/output/coadd_r_dir/"+path+" @"+DATADIR+"/patches_r.txt --selectId filter="+filter+" visit="+visitStr).split()))

    #Stack the patches
    ACTask = Assembler.AssembleCoaddTask
    res=ACTask.parseAndRun(args=((DATADIR+"/output/coadd_r_dir/"+path+" @"+DATADIR+"/patches_r.txt --selectId filter="+filter+" visit="+visitStr).split()))

# %% [markdown]
# Those are the science images around the day of the supernova maximum intensity

# %%
Coaddition(path='subtract+0', tract=0, filter='r', visitList=[850586])
Coaddition(path='subtract+1', tract=0, filter='r', visitList=[850588])
Coaddition(path='subtract-2', tract=0, filter='r', visitList=[850178])
Coaddition(path='subtract-1', tract=0, filter='r', visitList=[850181])
Coaddition(path='subtract+2', tract=0, filter='r', visitList=[850590])

# %% [markdown]
# These are the visits for the coaddition that will generate a template image

# %%
Coaddition(path='template', tract=0, filter='r', visitList=[996230, 996231, 996232, 996233, 996234, 995364, 995365, 995366, 995367, 995368])
# Out:
# 996230^996231^996232^996233^996234^995364^995365^995366^995367^995368

# %%
im1 = afwImage.ExposureF(DATADIR+"/output/coadd_r_dir/subtract-4/deepCoadd/r/0/11,24.fits")
displayImage(im1.getMaskedImage().getImage(),frame=0,title="coaddIm",path="images/coaddIm.png")
ds9.zoom(zoomfac=3, colc=363, rowc=632)
ds9.dot("o", 363  , 632 , frame=0, size = 25, ctype = ds9.RED)
showFrame(frame=0,title="SN!",path="images/SN.png")
# Out:
# ds9 doesn't appear to be running (XPA: XPA returned NULL, (;iconify no; raise)), I'll exec it for you
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# coaddIm
# SN!

# %% [markdown]
# # Subtraction:

# %%
scienceFolder = "subtract+0"
templateFolder = "template"

SciencePath = DATADIR+"/output/coadd_r_dir/"+scienceFolder+"/deepCoadd/r/0/11,24.fits"
TemplatePath = DATADIR+"/output/coadd_r_dir/"+templateFolder+"/deepCoadd/r/0/11,24.fits"
OutputPath = DATADIR+"/subtracted"

# %%
def SubtractImages(fwhm=None, templateImagePath=None, scienceImagePath=None):
    config = ipDiffim.ImagePsfMatchTask.ConfigClass()
    #Kernel name is Alard-Lupton by default
    config.kernel.name = "AL"
    subconfig = config.kernel.active
    #Fwhm will be calculated if none is provide
    defFwhm         = fwhm
    fwhmS = defFwhm
    fwhmT = defFwhm
    psfmatch = ipDiffim.ImagePsfMatchTask(config)

    #for image1, image2 in zip(Set1Files,Set2Files):
    #    print("Subtracting " + image1 + " " + image2)
    scienceImage = afwImage.ExposureF(scienceImagePath)
    templateImage = afwImage.ExposureF(templateImagePath)
    
    results  = psfmatch.subtractExposures(templateImage, scienceImage,
                            templateFwhmPix = fwhmT, scienceFwhmPix = fwhmS, doWarping=True)

    differenceExposure = results.subtractedExposure
    
    return differenceExposure

# %%
dif = SubtractImages(templateImagePath=TemplatePath, scienceImagePath=SciencePath)

# %%
displayImage(dif.getMaskedImage().getImage(),frame=0,title="difImage",path="images/diffFig.png")
# Out:
# ds9 doesn't appear to be running (XPA: XPA returned NULL, (;iconify no; raise)), I'll exec it for you
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# waiting for ds9...
# difImage

# %% [markdown]
# The two folders containing the images to subtract are defined

# %%
Set1Path = DATADIR+"/output/coadd_r_dir/deepCoadd/r/1/33,15.fits"
Set2Path = DATADIR+"/output/coadd_r_dir/subtract/deepCoadd/r/1/33,15.fits"
OutputPath = DATADIR+"/output/subtracted-inter"

# %% [markdown]
# The images are loaded and subtracted. Results are saved on disk.

# %%
config = ipDiffim.ImagePsfMatchTask.ConfigClass()
config.kernel.name = "AL"
subconfig = config.kernel.active
defFwhm         = 2.5
fwhmS = defFwhm
fwhmT = defFwhm
psfmatch = ipDiffim.ImagePsfMatchTask(config)

#for image1, image2 in zip(Set1Files,Set2Files):
#    print("Subtracting " + image1 + " " + image2)
firstImage = afwImage.ExposureF(Set1Path)
secondImage = afwImage.ExposureF(Set2Path)
    
results  = psfmatch.subtractExposures(firstImage, secondImage,
                            templateFwhmPix = fwhmT, scienceFwhmPix = fwhmS, doWarping=True)

differenceExposure = results.subtractedExposure

# %%
#differenceExposure.writeFits(OutputPath+'/33,15.fits')
import lsst.afw.display.ds9 as ds9

psf = results.psfMatchingKernel
kImageOut = afwImage.ImageD(psf.getDimensions())
ds9.mtv(kImageOut, frame=1)

im1psf = afwImage.ImageD(psf.getDimensions())


psf.computeImage(im1psf, False)
ds9.mtv(im1psf, frame=1)

import lsst.meas.algorithms.utils as measUtils
cellSet = results.kernelCellSet
measUtils.showPsfMosaic(results.matchedImage, psf=psf, frame=2)
#psfIm = psf.computeImage()
#ds9.mtv(psfIm, frame=frame, title="Psf Image"); frame += 1

#import lsst.meas.algorithms.utils as measUtils
#cellSet = results.kernelCellSet
#measUtils.showPsfMosaic(differenceExposure, psf=psf, frame=1)

# %%
print results.psfMatchingKernel.toString

import lsst.afw.display.ds9 as ds9
import time

arrow1sn =[(141,141),(160,160)]
arrow2sn =[(141,145),(141,141),(145,141)]

try:
    os.remove('fig1.png')
    os.remove('fig2.png')
    os.remove('fig3.png')
except(os.error):
    pass
#firstImage = afwImage.ExposureF(Set1Path)
ds9.mtv(firstImage, frame=1)
ds9.scale(type='zscale', frame=1)
ds9.zoom(4,141,141, frame=1)
ds9.setMaskTransparency(70, frame=1)
ds9.line(arrow1sn,ctype='red', frame=1)
ds9.line(arrow2sn,ctype='red', frame=1)
ds9.dot('look for the SN !',131,151, frame=1)
time.sleep(2)
ds9.ds9Cmd('saveimage fig1.png', frame=1)
time.sleep(2)


ds9.mtv(secondImage, frame=2)
ds9.scale(type='zscale', frame=2)
ds9.zoom(4,141,141, frame=2)
ds9.setMaskTransparency(70, frame=2)
ds9.line(arrow1sn,ctype='red', frame=2)
ds9.line(arrow2sn,ctype='red', frame=2)
ds9.dot('look for the SN !',131,151, frame=2)
time.sleep(2)
ds9.ds9Cmd('saveimage fig2.png', frame=2)
time.sleep(2)
ds9.mtv(differenceExposure, frame=3)
ds9.scale(type='zscale', frame=3)
ds9.zoom(4,141,141, frame=3)
ds9.setMaskTransparency(70, frame=3)
ds9.line(arrow1sn,ctype='red', frame=3)
ds9.line(arrow2sn,ctype='red', frame=3)
ds9.dot('look for the SN !',131,151, frame=3)
time.sleep(2)
ds9.ds9Cmd('saveimage fig3.png', frame=3)
time.sleep(2)


from IPython.display import Image, display_png
i1 =  Image(filename = 'fig1.png')
i2 = Image(filename = 'fig2.png')
i3 = Image(filename = 'fig3.png')
display_png(i1)
display_png(i2)
display_png(i3)

# %%
import lsst.pipe.tasks.processCoadd as CoaddProcesser

DATADIR2="/renoir_data_02/jpreyes/lsst_data/data/CFHTLS-4"

CPTask = CoaddProcesser.ProcessCoaddTask
#CPTask.parseAndRun(args=((DATASUB3+"/output/coadd_r_dir --output "+DATASUB3+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB3+"/patches_r.txt").split()))
CPTask.parseAndRun(args=((DATADIR2+"/output/coadd_r_dir --output "+DATADIR2+"/output/coadd_r_dir/deepCoaddDetect --id filter=r tract=1 patch=33,15 --config doCalibrate=False doWriteSourceMatches=False --clobber-config").split()))
#CPTask.parseAndRun(args=((DATASUB5+"/output/coadd_r_dir --output "+DATASUB5+"/output/coadd_r_dir/deepCoaddDetect @"+DATASUB5+"/patches_r.txt").split()))
